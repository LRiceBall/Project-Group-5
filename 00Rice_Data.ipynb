# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file1 = "Resources/Hot 100 Audio Features.csv"
file2 = "Resources/Hot Stuff.csv"

# %%
audio_features = pd.read_csv(file1)
hot100 = pd.read_csv(file2)

# %%
merge_df = pd.merge(audio_features, hot100, on=["Song", "Performer", "SongID"], how="outer")
merge_df.head()
# Out:
#                                               SongID                Performer  \
# 0                      AdictoTainy, Anuel AA & Ozuna  Tainy, Anuel AA & Ozuna
# 1                      AdictoTainy, Anuel AA & Ozuna  Tainy, Anuel AA & Ozuna
# 2  The Ones That Didn't Make It Back HomeJustin M...             Justin Moore
# 3  The Ones That Didn't Make It Back HomeJustin M...             Justin Moore
# 4  The Ones That Didn't Make It Back HomeJustin M...             Justin Moore
#
#                                      Song  \
# 0                                  Adicto
# 1                                  Adicto
# 2  The Ones That Didn't Make It Back Home
# 3  The Ones That Didn't Make It Back Home
# 4  The Ones That Didn't Make It Back Home
#
#                                        spotify_genre        spotify_track_id  \
# 0                                  ['pop reggaeton']  3jbT1Y5MoPwEIpZndDDwVq
# 1                                  ['pop reggaeton']  3jbT1Y5MoPwEIpZndDDwVq
# 2  ['arkansas country', 'contemporary country', '...                     NaN
# 3  ['arkansas country', 'contemporary country', '...                     NaN
# 4  ['arkansas country', 'contemporary country', '...                     NaN
#
#   spotify_track_preview_url             spotify_track_album  \
# 0                       NaN  Adicto (with Anuel AA & Ozuna)
# 1                       NaN  Adicto (with Anuel AA & Ozuna)
# 2                       NaN                             NaN
# 3                       NaN                             NaN
# 4                       NaN                             NaN
#
#   spotify_track_explicit  spotify_track_duration_ms  spotify_track_popularity  \
# 0                  False                   270740.0                      91.0
# 1                  False                   270740.0                      91.0
# 2                    NaN                        NaN                       NaN
# 3                    NaN                        NaN                       NaN
# 4                    NaN                        NaN                       NaN
#
#    ...  valence   tempo  time_signature  \
# 0  ...    0.623  80.002             4.0
# 1  ...    0.623  80.002             4.0
# 2  ...      NaN     NaN             NaN
# 3  ...      NaN     NaN             NaN
# 4  ...      NaN     NaN             NaN
#
#                                                  url      WeekID  \
# 0  https://www.billboard.com/charts/hot-100/2019-...   10/5/2019
# 1  https://www.billboard.com/charts/hot-100/2019-...  10/12/2019
# 2  https://www.billboard.com/charts/hot-100/2019-...   6/29/2019
# 3  https://www.billboard.com/charts/hot-100/2019-...    7/6/2019
# 4  https://www.billboard.com/charts/hot-100/2019-...   7/13/2019
#
#    Week Position  Instance  Previous Week Position  Peak Position  \
# 0           86.0       1.0                     NaN           86.0
# 1           98.0       1.0                    86.0           86.0
# 2          100.0       1.0                     NaN          100.0
# 3           93.0       1.0                   100.0           93.0
# 4           95.0       1.0                    93.0           93.0
#
#    Weeks on Chart
# 0             1.0
# 1             2.0
# 2             1.0
# 3             2.0
# 4             3.0
#
# [5 rows x 29 columns]

# %%
# merge csv by columns
merge_df.columns
# Out:
# Index(['SongID', 'Performer', 'Song', 'spotify_genre', 'spotify_track_id',
#        'spotify_track_preview_url', 'spotify_track_album',
#        'spotify_track_explicit', 'spotify_track_duration_ms',
#        'spotify_track_popularity', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'url', 'WeekID', 'Week Position',
#        'Instance', 'Previous Week Position', 'Peak Position',
#        'Weeks on Chart'],
#       dtype='object')

# %%
# select desired columns
reduced_df = merge_df[['Performer', 'Song', 'spotify_genre', 'spotify_track_duration_ms',
                       'spotify_track_popularity', 'danceability', 'energy', 'loudness', 'valence', 
                       'tempo', 'WeekID', 'Week Position', 'Previous Week Position', 'Peak Position',
                       'Weeks on Chart']]
reduced_df
# Out:
#                       Performer                                    Song  \
# 0       Tainy, Anuel AA & Ozuna                                  Adicto
# 1       Tainy, Anuel AA & Ozuna                                  Adicto
# 2                  Justin Moore  The Ones That Didn't Make It Back Home
# 3                  Justin Moore  The Ones That Didn't Make It Back Home
# 4                  Justin Moore  The Ones That Didn't Make It Back Home
# ...                         ...                                     ...
# 322868         Jackie DeShannon                            Vanilla Ólay
# 322869         Jackie DeShannon                            Vanilla Ólay
# 322870             XXXTENTACION      Everybody Dies In Their Nightmares
# 322871             XXXTENTACION      Everybody Dies In Their Nightmares
# 322872             XXXTENTACION      Everybody Dies In Their Nightmares
#
#                                             spotify_genre  \
# 0                                       ['pop reggaeton']
# 1                                       ['pop reggaeton']
# 2       ['arkansas country', 'contemporary country', '...
# 3       ['arkansas country', 'contemporary country', '...
# 4       ['arkansas country', 'contemporary country', '...
# ...                                                   ...
# 322868                                                NaN
# 322869                                                NaN
# 322870                                                NaN
# 322871                                                NaN
# 322872                                                NaN
#
#         spotify_track_duration_ms  spotify_track_popularity  danceability  \
# 0                        270740.0                      91.0         0.734
# 1                        270740.0                      91.0         0.734
# 2                             NaN                       NaN           NaN
# 3                             NaN                       NaN           NaN
# 4                             NaN                       NaN           NaN
# ...                           ...                       ...           ...
# 322868                        NaN                       NaN           NaN
# 322869                        NaN                       NaN           NaN
# 322870                        NaN                       NaN           NaN
# 322871                        NaN                       NaN           NaN
# 322872                        NaN                       NaN           NaN
#
#         energy  loudness  valence   tempo      WeekID  Week Position  \
# 0        0.836    -4.803    0.623  80.002   10/5/2019           86.0
# 1        0.836    -4.803    0.623  80.002  10/12/2019           98.0
# 2          NaN       NaN      NaN     NaN   6/29/2019          100.0
# 3          NaN       NaN      NaN     NaN    7/6/2019           93.0
# 4          NaN       NaN      NaN     NaN   7/13/2019           95.0
# ...        ...       ...      ...     ...         ...            ...
# 322868     NaN       NaN      NaN     NaN   7/22/1972           76.0
# 322869     NaN       NaN      NaN     NaN   7/29/1972           76.0
# 322870     NaN       NaN      NaN     NaN   6/30/2018           42.0
# 322871     NaN       NaN      NaN     NaN    7/7/2018           46.0
# 322872     NaN       NaN      NaN     NaN   7/14/2018           91.0
#
#         Previous Week Position  Peak Position  Weeks on Chart
# 0                          NaN           86.0             1.0
# 1                         86.0           86.0             2.0
# 2                          NaN          100.0             1.0
# 3                        100.0           93.0             2.0
# 4                         93.0           93.0             3.0
# ...                        ...            ...             ...
# 322868                    80.0           76.0             8.0
# 322869                    76.0           76.0             9.0
# 322870                     NaN           42.0             5.0
# 322871                    42.0           42.0             6.0
# 322872                    46.0           42.0             7.0
#
# [322873 rows x 15 columns]

# %%
# rename columns
reduced_df= reduced_df.rename(columns={'spotify_genre': 'Genre', 'energy': 'Energy',
                                       'loudness': 'Loudness'})

# %%
# reduce columns for energy and loudness
attributes_df = reduced_df[['Performer', 'Song', 'Genre', 'Energy', 'Loudness', 
                       'WeekID', 'Week Position', 'Previous Week Position', 'Peak Position',
                       'Weeks on Chart']]
attributes_df
# Out:
#                       Performer                                    Song  \
# 0       Tainy, Anuel AA & Ozuna                                  Adicto
# 1       Tainy, Anuel AA & Ozuna                                  Adicto
# 2                  Justin Moore  The Ones That Didn't Make It Back Home
# 3                  Justin Moore  The Ones That Didn't Make It Back Home
# 4                  Justin Moore  The Ones That Didn't Make It Back Home
# ...                         ...                                     ...
# 322868         Jackie DeShannon                            Vanilla Ólay
# 322869         Jackie DeShannon                            Vanilla Ólay
# 322870             XXXTENTACION      Everybody Dies In Their Nightmares
# 322871             XXXTENTACION      Everybody Dies In Their Nightmares
# 322872             XXXTENTACION      Everybody Dies In Their Nightmares
#
#                                                     Genre  Energy  Loudness  \
# 0                                       ['pop reggaeton']   0.836    -4.803
# 1                                       ['pop reggaeton']   0.836    -4.803
# 2       ['arkansas country', 'contemporary country', '...     NaN       NaN
# 3       ['arkansas country', 'contemporary country', '...     NaN       NaN
# 4       ['arkansas country', 'contemporary country', '...     NaN       NaN
# ...                                                   ...     ...       ...
# 322868                                                NaN     NaN       NaN
# 322869                                                NaN     NaN       NaN
# 322870                                                NaN     NaN       NaN
# 322871                                                NaN     NaN       NaN
# 322872                                                NaN     NaN       NaN
#
#             WeekID  Week Position  Previous Week Position  Peak Position  \
# 0        10/5/2019           86.0                     NaN           86.0
# 1       10/12/2019           98.0                    86.0           86.0
# 2        6/29/2019          100.0                     NaN          100.0
# 3         7/6/2019           93.0                   100.0           93.0
# 4        7/13/2019           95.0                    93.0           93.0
# ...            ...            ...                     ...            ...
# 322868   7/22/1972           76.0                    80.0           76.0
# 322869   7/29/1972           76.0                    76.0           76.0
# 322870   6/30/2018           42.0                     NaN           42.0
# 322871    7/7/2018           46.0                    42.0           42.0
# 322872   7/14/2018           91.0                    46.0           42.0
#
#         Weeks on Chart
# 0                  1.0
# 1                  2.0
# 2                  1.0
# 3                  2.0
# 4                  3.0
# ...                ...
# 322868             8.0
# 322869             9.0
# 322870             5.0
# 322871             6.0
# 322872             7.0
#
# [322873 rows x 10 columns]

# %%
# number of times a song is in the top 100
attributes_df["Song"].value_counts()
# Out:
# Stay                                              207
# Angel                                             205
# Heaven                                            194
# Hold On                                           189
# I Like It                                         188
#                                                  ...
# Heatstroke                                          1
# Sparks                                              1
# I Think                                             1
# This World We Love In (Il Cielo In Una Stanza)      1
# You Make Me                                         1
# Name: Song, Length: 23631, dtype: int64

# %%
# select only songs in top 40
top40 = attributes_df.loc[attributes_df['Week Position'] <= 40, :]
top40.dropna(subset=['Energy', 'Loudness', 'Weeks on Chart'])
top40
# Out:
#                                   Performer            Song  \
# 18               Lady Gaga & Bradley Cooper         Shallow
# 19               Lady Gaga & Bradley Cooper         Shallow
# 20               Lady Gaga & Bradley Cooper         Shallow
# 21               Lady Gaga & Bradley Cooper         Shallow
# 23               Lady Gaga & Bradley Cooper         Shallow
# ...                                     ...             ...
# 322832                       Spandau Ballet            True
# 322846  XXXTENTACION Featuring Trippie Redd       F**k Love
# 322847  XXXTENTACION Featuring Trippie Redd       F**k Love
# 322857                         XXXTENTACION  Jocelyn Flores
# 322858                         XXXTENTACION  Jocelyn Flores
#
#                        Genre  Energy  Loudness      WeekID  Week Position  \
# 18      ['dance pop', 'pop']   0.385    -6.362  10/13/2018           28.0
# 19      ['dance pop', 'pop']   0.385    -6.362   12/1/2018           23.0
# 20      ['dance pop', 'pop']   0.385    -6.362    2/2/2019           24.0
# 21      ['dance pop', 'pop']   0.385    -6.362    2/9/2019           16.0
# 23      ['dance pop', 'pop']   0.385    -6.362   12/8/2018           28.0
# ...                      ...     ...       ...         ...            ...
# 322832                   NaN     NaN       NaN  11/19/1983           21.0
# 322846                   NaN     NaN       NaN   6/30/2018           28.0
# 322847                   NaN     NaN       NaN    7/7/2018           34.0
# 322857                   NaN     NaN       NaN   6/30/2018           19.0
# 322858                   NaN     NaN       NaN    7/7/2018           25.0
#
#         Previous Week Position  Peak Position  Weeks on Chart
# 18                         NaN           28.0             1.0
# 19                        24.0            5.0             8.0
# 20                        24.0            5.0            17.0
# 21                        24.0            5.0            18.0
# 23                        23.0            5.0             9.0
# ...                        ...            ...             ...
# 322832                    12.0            4.0            16.0
# 322846                     NaN           28.0            19.0
# 322847                    28.0           28.0            20.0
# 322857                     NaN           19.0            17.0
# 322858                    19.0           19.0            18.0
#
# [129462 rows x 10 columns]

# %%
# each time a song is listed as being in the top 100 the "weeks on chart" is the moist CURRENT number
    # there for all different
# get the highest amount of weeks a song has been in the top 40.
top40_song = top40.groupby(['Performer','Song'], as_index=False)

max_weeks = top40_song['Weeks on Chart'].max()
max_weeks
# Out:
#                                               Performer  \
# 0                                "Little" Jimmy Dickens
# 1                                   "Weird Al" Yankovic
# 2                                   "Weird Al" Yankovic
# 3                                   "Weird Al" Yankovic
# 4                                   "Weird Al" Yankovic
# ...                                                 ...
# 12846                                         will.i.am
# 12847                        will.i.am & Britney Spears
# 12848                           will.i.am & Nicki Minaj
# 12849                 will.i.am Featuring Justin Bieber
# 12850  will.i.am Featuring Mick Jagger & Jennifer Lopez
#
#                                             Song  Weeks on Chart
# 0      May The Bird Of Paradise Fly Up Your Nose             9.0
# 1                                         Eat It             8.0
# 2                            Smells Like Nirvana             4.0
# 3                                  White & Nerdy            15.0
# 4                                    Word Crimes             1.0
# ...                                          ...             ...
# 12846                      I Got It From My Mama             5.0
# 12847                             Scream & Shout            23.0
# 12848                               Check It Out             9.0
# 12849                                 #thatPOWER            12.0
# 12850                   T.H.E (The Hardest Ever)             1.0
#
# [12851 rows x 3 columns]

# %%
# sort by frequency on top 40
ranking_songs = max_weeks.sort_values("Weeks on Chart", ascending=False)
ranking_songs
# Out:
#                                               Performer  \
# 4984                                    Imagine Dragons
# 157                                          AWOLNATION
# 5348                                         Jason Mraz
# 6581                                        LeAnn Rimes
# 205                                               Adele
# ...                                                 ...
# 6699                                       Lil Uzi Vert
# 6702                                       Lil Uzi Vert
# 6707                                          Lil Wayne
# 6708                                          Lil Wayne
# 12850  will.i.am Featuring Mick Jagger & Jennifer Lopez
#
#                            Song  Weeks on Chart
# 4984                Radioactive            84.0
# 157                        Sail            76.0
# 5348                  I'm Yours            74.0
# 6581              How Do I Live            64.0
# 205         Rolling In The Deep            63.0
# ...                         ...             ...
# 6699        Futsal Shuffle 2020             1.0
# 6702          The Way Life Goes             1.0
# 6707               Blunt Blowin             1.0
# 6708            Can't Be Broken             1.0
# 12850  T.H.E (The Hardest Ever)             1.0
#
# [12851 rows x 3 columns]

# %%
# reduce columns to focus on loudness
loudness_df = top40[['Performer', 'Song', 'Genre', 'Loudness', 'Peak Position', 'Weeks on Chart']]
loudness_df
# Out:
#                                   Performer            Song  \
# 18               Lady Gaga & Bradley Cooper         Shallow
# 19               Lady Gaga & Bradley Cooper         Shallow
# 20               Lady Gaga & Bradley Cooper         Shallow
# 21               Lady Gaga & Bradley Cooper         Shallow
# 23               Lady Gaga & Bradley Cooper         Shallow
# ...                                     ...             ...
# 322832                       Spandau Ballet            True
# 322846  XXXTENTACION Featuring Trippie Redd       F**k Love
# 322847  XXXTENTACION Featuring Trippie Redd       F**k Love
# 322857                         XXXTENTACION  Jocelyn Flores
# 322858                         XXXTENTACION  Jocelyn Flores
#
#                        Genre  Loudness  Peak Position  Weeks on Chart
# 18      ['dance pop', 'pop']    -6.362           28.0             1.0
# 19      ['dance pop', 'pop']    -6.362            5.0             8.0
# 20      ['dance pop', 'pop']    -6.362            5.0            17.0
# 21      ['dance pop', 'pop']    -6.362            5.0            18.0
# 23      ['dance pop', 'pop']    -6.362            5.0             9.0
# ...                      ...       ...            ...             ...
# 322832                   NaN       NaN            4.0            16.0
# 322846                   NaN       NaN           28.0            19.0
# 322847                   NaN       NaN           28.0            20.0
# 322857                   NaN       NaN           19.0            17.0
# 322858                   NaN       NaN           19.0            18.0
#
# [129462 rows x 6 columns]

# %%
# remove NaN values in the genre and loudness columns
loudness_df = loudness_df[loudness_df['Genre'].notna()]
loudness_df = loudness_df[loudness_df['Loudness'].notna()]
loudness_df
# Out:
#                          Performer                 Song  \
# 18      Lady Gaga & Bradley Cooper              Shallow
# 19      Lady Gaga & Bradley Cooper              Shallow
# 20      Lady Gaga & Bradley Cooper              Shallow
# 21      Lady Gaga & Bradley Cooper              Shallow
# 23      Lady Gaga & Bradley Cooper              Shallow
# ...                            ...                  ...
# 320908               Solomon Burke  Tonight's The Night
# 320909               Solomon Burke  Tonight's The Night
# 320910               Solomon Burke  Tonight's The Night
# 320911               Solomon Burke  Tonight's The Night
# 320912               Solomon Burke  Tonight's The Night
#
#                                                     Genre  Loudness  \
# 18                                   ['dance pop', 'pop']    -6.362
# 19                                   ['dance pop', 'pop']    -6.362
# 20                                   ['dance pop', 'pop']    -6.362
# 21                                   ['dance pop', 'pop']    -6.362
# 23                                   ['dance pop', 'pop']    -6.362
# ...                                                   ...       ...
# 320908  ['brill building pop', 'classic soul', 'funk',...    -9.534
# 320909  ['brill building pop', 'classic soul', 'funk',...    -9.534
# 320910  ['brill building pop', 'classic soul', 'funk',...    -9.534
# 320911  ['brill building pop', 'classic soul', 'funk',...    -9.534
# 320912  ['brill building pop', 'classic soul', 'funk',...    -9.534
#
#         Peak Position  Weeks on Chart
# 18               28.0             1.0
# 19                5.0             8.0
# 20                5.0            17.0
# 21                5.0            18.0
# 23                5.0             9.0
# ...               ...             ...
# 320908           32.0             6.0
# 320909           29.0             7.0
# 320910           28.0             8.0
# 320911           28.0             9.0
# 320912           28.0            10.0
#
# [115153 rows x 6 columns]

# %%
# get the max loudness value
loudness_df['Loudness'].max()
# Out:
# -0.507

# %%
# get the min loudness value
loudness_df['Loudness'].min()
# Out:
# -27.01

# %%
# create a new column in bins based on loudness
loud_bins = [-30, -25, -20, -15, -10, -5, 0]
loud_labels = ['-30 to -26', '-25 to -21', '-20 to -16', '-15 to -11', '-10 to -6', '-5 to 0']

loudness_df["Loudness Category"] = pd.cut(loudness_df["Loudness"], loud_bins, 
                                          labels=loud_labels, right=False)
loudness_df
# Out:
#                          Performer                 Song  \
# 18      Lady Gaga & Bradley Cooper              Shallow
# 19      Lady Gaga & Bradley Cooper              Shallow
# 20      Lady Gaga & Bradley Cooper              Shallow
# 21      Lady Gaga & Bradley Cooper              Shallow
# 23      Lady Gaga & Bradley Cooper              Shallow
# ...                            ...                  ...
# 320908               Solomon Burke  Tonight's The Night
# 320909               Solomon Burke  Tonight's The Night
# 320910               Solomon Burke  Tonight's The Night
# 320911               Solomon Burke  Tonight's The Night
# 320912               Solomon Burke  Tonight's The Night
#
#                                                     Genre  Loudness  \
# 18                                   ['dance pop', 'pop']    -6.362
# 19                                   ['dance pop', 'pop']    -6.362
# 20                                   ['dance pop', 'pop']    -6.362
# 21                                   ['dance pop', 'pop']    -6.362
# 23                                   ['dance pop', 'pop']    -6.362
# ...                                                   ...       ...
# 320908  ['brill building pop', 'classic soul', 'funk',...    -9.534
# 320909  ['brill building pop', 'classic soul', 'funk',...    -9.534
# 320910  ['brill building pop', 'classic soul', 'funk',...    -9.534
# 320911  ['brill building pop', 'classic soul', 'funk',...    -9.534
# 320912  ['brill building pop', 'classic soul', 'funk',...    -9.534
#
#         Peak Position  Weeks on Chart Loudness Category
# 18               28.0             1.0         -10 to -6
# 19                5.0             8.0         -10 to -6
# 20                5.0            17.0         -10 to -6
# 21                5.0            18.0         -10 to -6
# 23                5.0             9.0         -10 to -6
# ...               ...             ...               ...
# 320908           32.0             6.0         -10 to -6
# 320909           29.0             7.0         -10 to -6
# 320910           28.0             8.0         -10 to -6
# 320911           28.0             9.0         -10 to -6
# 320912           28.0            10.0         -10 to -6
#
# [115153 rows x 7 columns]

# %%
loudness_df.plot.scatter(x='Weeks on Chart', y='Loudness', grid=True, figsize=(20,8),
                        title= 'Loudness vs Weeks in Top 40')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
loudness_df.plot.scatter(x='Peak Position', y='Loudness', grid=True, figsize=(20,8),
                        title= 'Loudness vs Weeks in Top 40')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# group data by song & disple with loud category
loud_ranking_song = loudness_df.groupby(['Song', "Loudness Category"], as_index=False)
loud_ranking_max = loud_ranking_song['Weeks on Chart'].max()
loud_ranking_max = loud_ranking_max.dropna(subset=['Weeks on Chart'])
loud_ranking_max
# Out:
#                                         Song Loudness Category  Weeks on Chart
# 4      "Cherry Cherry" from Hot August Night         -10 to -6             9.0
# 10                                        #1         -10 to -6            16.0
# 15                                  #9 Dream        -15 to -11            11.0
# 22                                #Beautiful         -10 to -6            11.0
# 29                                   #SELFIE           -5 to 0             7.0
# ...                                      ...               ...             ...
# 60015                    everything i wanted        -15 to -11             6.0
# 60022                              halfcrazy         -10 to -6            24.0
# 60028                                      i         -10 to -6             1.0
# 60034                                   iSpy         -10 to -6            29.0
# 60041                     whoa (mind in awe)           -5 to 0             1.0
#
# [10676 rows x 3 columns]

# %%
# take the max weeks a song is on the top 40 and show the highest rankers
loud_ranking = loud_ranking_max.sort_values("Weeks on Chart", ascending=False).dropna(subset=['Weeks on Chart'])
loud_ranking
# Out:
#                             Song Loudness Category  Weeks on Chart
# 39485                Radioactive           -5 to 0            84.0
# 41566                       Sail         -10 to -6            76.0
# 24292                  I'm Yours         -10 to -6            74.0
# 20302              How Do I Live         -10 to -6            64.0
# 40954        Rolling In The Deep         -10 to -6            63.0
# ...                          ...               ...             ...
# 17105               Good Morning           -5 to 0             1.0
# 17308                   Gorgeous         -10 to -6             1.0
# 17482                    Grammys         -10 to -6             1.0
# 17512  Great Is Thy Faithfulness         -10 to -6             1.0
# 60041         whoa (mind in awe)           -5 to 0             1.0
#
# [10676 rows x 3 columns]

# %%
#loud_barchart = loud_ranking.plot(kind='bar')
#loud_barchart.set_xlabel('Loudness Category')
#loud_barchart.set_ylabel('Weeks on Chart')
#plt.show()

# %%
loud_groups = loud_ranking.groupby('Loudness Category')
loud_category = loud_groups['Weeks on Chart'].mean()

# %%
loud_cat_chart = loud_category.plot.bar(title ='Loudness on Charts')
loud_cat_chart.set_xlabel('Loudness Category')
loud_cat_chart.set_ylabel('Avg Weeks on Charts')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
loud_ranking_song2 = loudness_df.groupby(['Song', "Loudness Category"], as_index=False)
loud_ranking_max2 = loud_ranking_song2['Peak Position'].max()
loud_ranking_max2 = loud_ranking_max2.dropna(subset=['Peak Position'])
loud_ranking_max2
# Out:
#                                         Song Loudness Category  Peak Position
# 4      "Cherry Cherry" from Hot August Night         -10 to -6           36.0
# 10                                        #1         -10 to -6           40.0
# 15                                  #9 Dream        -15 to -11           35.0
# 22                                #Beautiful         -10 to -6           24.0
# 29                                   #SELFIE           -5 to 0           28.0
# ...                                      ...               ...            ...
# 60015                    everything i wanted        -15 to -11            8.0
# 60022                              halfcrazy         -10 to -6           34.0
# 60028                                      i         -10 to -6           39.0
# 60034                                   iSpy         -10 to -6           32.0
# 60041                     whoa (mind in awe)           -5 to 0           37.0
#
# [10676 rows x 3 columns]

# %%
loud_ranking2 = loud_ranking_max2.sort_values("Peak Position", ascending=True).dropna(subset=['Peak Position'])
loud_ranking2
# Out:
#                                Song Loudness Category  Peak Position
# 51664               This Is America         -10 to -6            1.0
# 16475                 Give It To Me           -5 to 0            1.0
# 29735                Live Your Life           -5 to 0            1.0
# 12214          Doo Wop (That Thing)         -10 to -6            1.0
# 21328  I Don't Want To Miss A Thing         -10 to -6            1.0
# ...                             ...               ...            ...
# 28144               Lawyers In Love         -10 to -6           40.0
# 52714       Too Late To Say Goodbye         -10 to -6           40.0
# 52702               Too Hot Ta Trot         -10 to -6           40.0
# 32289                 Mary's Prayer        -15 to -11           40.0
# 36646       One For The Mockingbird         -10 to -6           40.0
#
# [10676 rows x 3 columns]

# %%
#loud_barchart2 = loud_ranking.plot(kind='bar')
#loud_barchart2.set_xlabel('Loudness Category')
#loud_barchart2.set_ylabel('Peak Position')
#plt.show()

# %%
loud_groups2 = loud_ranking2.groupby('Loudness Category')
loud_category2 = loud_groups2['Peak Position'].mean()

# %%
loud_cat_chart2 = loud_category2.plot.bar(title ='Loudness on Charts')
loud_cat_chart2.set_xlabel('Loudness Category')
loud_cat_chart2.set_ylabel('Avg Peak Postion')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# reduce columns to focus on energy
energy_df = top40[['Performer', 'Song', 'Genre', 'Energy', 'Peak Position', 'Weeks on Chart']]
energy_df
# Out:
#                                   Performer            Song  \
# 18               Lady Gaga & Bradley Cooper         Shallow
# 19               Lady Gaga & Bradley Cooper         Shallow
# 20               Lady Gaga & Bradley Cooper         Shallow
# 21               Lady Gaga & Bradley Cooper         Shallow
# 23               Lady Gaga & Bradley Cooper         Shallow
# ...                                     ...             ...
# 322832                       Spandau Ballet            True
# 322846  XXXTENTACION Featuring Trippie Redd       F**k Love
# 322847  XXXTENTACION Featuring Trippie Redd       F**k Love
# 322857                         XXXTENTACION  Jocelyn Flores
# 322858                         XXXTENTACION  Jocelyn Flores
#
#                        Genre  Energy  Peak Position  Weeks on Chart
# 18      ['dance pop', 'pop']   0.385           28.0             1.0
# 19      ['dance pop', 'pop']   0.385            5.0             8.0
# 20      ['dance pop', 'pop']   0.385            5.0            17.0
# 21      ['dance pop', 'pop']   0.385            5.0            18.0
# 23      ['dance pop', 'pop']   0.385            5.0             9.0
# ...                      ...     ...            ...             ...
# 322832                   NaN     NaN            4.0            16.0
# 322846                   NaN     NaN           28.0            19.0
# 322847                   NaN     NaN           28.0            20.0
# 322857                   NaN     NaN           19.0            17.0
# 322858                   NaN     NaN           19.0            18.0
#
# [129462 rows x 6 columns]

# %%
# remove NaN values in genre and energy columns
energy_df = energy_df[energy_df['Genre'].notna()]
energy_df = energy_df[energy_df['Energy'].notna()]
energy_df
# Out:
#                          Performer                 Song  \
# 18      Lady Gaga & Bradley Cooper              Shallow
# 19      Lady Gaga & Bradley Cooper              Shallow
# 20      Lady Gaga & Bradley Cooper              Shallow
# 21      Lady Gaga & Bradley Cooper              Shallow
# 23      Lady Gaga & Bradley Cooper              Shallow
# ...                            ...                  ...
# 320908               Solomon Burke  Tonight's The Night
# 320909               Solomon Burke  Tonight's The Night
# 320910               Solomon Burke  Tonight's The Night
# 320911               Solomon Burke  Tonight's The Night
# 320912               Solomon Burke  Tonight's The Night
#
#                                                     Genre  Energy  \
# 18                                   ['dance pop', 'pop']   0.385
# 19                                   ['dance pop', 'pop']   0.385
# 20                                   ['dance pop', 'pop']   0.385
# 21                                   ['dance pop', 'pop']   0.385
# 23                                   ['dance pop', 'pop']   0.385
# ...                                                   ...     ...
# 320908  ['brill building pop', 'classic soul', 'funk',...   0.476
# 320909  ['brill building pop', 'classic soul', 'funk',...   0.476
# 320910  ['brill building pop', 'classic soul', 'funk',...   0.476
# 320911  ['brill building pop', 'classic soul', 'funk',...   0.476
# 320912  ['brill building pop', 'classic soul', 'funk',...   0.476
#
#         Peak Position  Weeks on Chart
# 18               28.0             1.0
# 19                5.0             8.0
# 20                5.0            17.0
# 21                5.0            18.0
# 23                5.0             9.0
# ...               ...             ...
# 320908           32.0             6.0
# 320909           29.0             7.0
# 320910           28.0             8.0
# 320911           28.0             9.0
# 320912           28.0            10.0
#
# [115153 rows x 6 columns]

# %%
# get the max loudness value
energy_df['Energy'].max()
# Out:
# 0.997

# %%
# get the min loudness value
energy_df['Energy'].min()
# Out:
# 0.0201

# %%
# create a new column in bins based on loudness
energy_bins = [0, .2, .4, .6, .8, 1]
energy_labels = ['0.0 to 0.2', '0.21 to 0.4', '0.41 to 0.6', '0.61 to 0.8', '0.81 to 1']

energy_df["Energy Category"] = pd.cut(energy_df["Energy"], energy_bins, 
                                          labels=energy_labels, right=False)
energy_df
# Out:
#                          Performer                 Song  \
# 18      Lady Gaga & Bradley Cooper              Shallow
# 19      Lady Gaga & Bradley Cooper              Shallow
# 20      Lady Gaga & Bradley Cooper              Shallow
# 21      Lady Gaga & Bradley Cooper              Shallow
# 23      Lady Gaga & Bradley Cooper              Shallow
# ...                            ...                  ...
# 320908               Solomon Burke  Tonight's The Night
# 320909               Solomon Burke  Tonight's The Night
# 320910               Solomon Burke  Tonight's The Night
# 320911               Solomon Burke  Tonight's The Night
# 320912               Solomon Burke  Tonight's The Night
#
#                                                     Genre  Energy  \
# 18                                   ['dance pop', 'pop']   0.385
# 19                                   ['dance pop', 'pop']   0.385
# 20                                   ['dance pop', 'pop']   0.385
# 21                                   ['dance pop', 'pop']   0.385
# 23                                   ['dance pop', 'pop']   0.385
# ...                                                   ...     ...
# 320908  ['brill building pop', 'classic soul', 'funk',...   0.476
# 320909  ['brill building pop', 'classic soul', 'funk',...   0.476
# 320910  ['brill building pop', 'classic soul', 'funk',...   0.476
# 320911  ['brill building pop', 'classic soul', 'funk',...   0.476
# 320912  ['brill building pop', 'classic soul', 'funk',...   0.476
#
#         Peak Position  Weeks on Chart Energy Category
# 18               28.0             1.0     0.21 to 0.4
# 19                5.0             8.0     0.21 to 0.4
# 20                5.0            17.0     0.21 to 0.4
# 21                5.0            18.0     0.21 to 0.4
# 23                5.0             9.0     0.21 to 0.4
# ...               ...             ...             ...
# 320908           32.0             6.0     0.41 to 0.6
# 320909           29.0             7.0     0.41 to 0.6
# 320910           28.0             8.0     0.41 to 0.6
# 320911           28.0             9.0     0.41 to 0.6
# 320912           28.0            10.0     0.41 to 0.6
#
# [115153 rows x 7 columns]

# %%
energy_df.plot.scatter(x='Weeks on Chart', y='Energy', grid=True, figsize=(20,8),
                        title= 'Energy vs Weeks in Top 40')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
energy_df.plot.scatter(x='Peak Position', y='Energy', grid=True, figsize=(20,8),
                        title= 'Loudness vs Weeks in Top 40')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
energy_ranking_song = energy_df.groupby(['Song', "Energy Category"], as_index=False)
energy_ranking_max = energy_ranking_song['Weeks on Chart'].max()
energy_ranking_max = energy_ranking_max.dropna(subset=['Weeks on Chart'])
energy_ranking_max
# Out:
#                                         Song Energy Category  Weeks on Chart
# 4      "Cherry Cherry" from Hot August Night       0.81 to 1             9.0
# 8                                         #1     0.61 to 0.8            16.0
# 12                                  #9 Dream     0.41 to 0.6            11.0
# 18                                #Beautiful     0.61 to 0.8            11.0
# 24                                   #SELFIE       0.81 to 1             7.0
# ...                                      ...             ...             ...
# 50011                    everything i wanted     0.21 to 0.4             6.0
# 50018                              halfcrazy     0.61 to 0.8            24.0
# 50024                                      i       0.81 to 1             1.0
# 50028                                   iSpy     0.61 to 0.8            29.0
# 50032                     whoa (mind in awe)     0.41 to 0.6             1.0
#
# [10770 rows x 3 columns]

# %%
# take the max weeks a song is on the top 40 and show the highest rankers
energy_ranking = energy_ranking_max.sort_values("Weeks on Chart", ascending=False).dropna(subset=['Weeks on Chart'])
energy_ranking
# Out:
#                       Song Energy Category  Weeks on Chart
# 32903          Radioactive     0.61 to 0.8            84.0
# 34637                 Sail     0.41 to 0.6            76.0
# 20242            I'm Yours     0.41 to 0.6            74.0
# 16917        How Do I Live     0.41 to 0.6            64.0
# 34128  Rolling In The Deep     0.61 to 0.8            63.0
# ...                    ...             ...             ...
# 14163            Gonorrhea     0.61 to 0.8             1.0
# 14214           Good Girls       0.81 to 1             1.0
# 14254         Good Morning       0.81 to 1             1.0
# 45577        Walk On Water     0.41 to 0.6             1.0
# 50032   whoa (mind in awe)     0.41 to 0.6             1.0
#
# [10770 rows x 3 columns]

# %%
#energy_barchart = energy_ranking.plot(kind='bar')
#energy_barchart.set_xlabel('Energy Category')
#energy_barchart.set_ylabel('Weeks on Chart')
#plt.show()

# %%
energy_groups = energy_ranking.groupby('Energy Category')
energy_category = energy_groups['Weeks on Chart'].mean()

# %%
energy_cat_chart = energy_category.plot.bar(title ='Energy on Charts')
energy_cat_chart.set_xlabel('Energy Category')
energy_cat_chart.set_ylabel('Avg Weeks on Charts')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
energy_ranking_song2 = energy_df.groupby(['Song', "Energy Category"], as_index=False)
energy_ranking_max2 = energy_ranking_song2['Peak Position'].max()
energy_ranking_max2 = energy_ranking_max2.dropna(subset=['Peak Position'])
energy_ranking_max2
# Out:
#                                         Song Energy Category  Peak Position
# 4      "Cherry Cherry" from Hot August Night       0.81 to 1           36.0
# 8                                         #1     0.61 to 0.8           40.0
# 12                                  #9 Dream     0.41 to 0.6           35.0
# 18                                #Beautiful     0.61 to 0.8           24.0
# 24                                   #SELFIE       0.81 to 1           28.0
# ...                                      ...             ...            ...
# 50011                    everything i wanted     0.21 to 0.4            8.0
# 50018                              halfcrazy     0.61 to 0.8           34.0
# 50024                                      i       0.81 to 1           39.0
# 50028                                   iSpy     0.61 to 0.8           32.0
# 50032                     whoa (mind in awe)     0.41 to 0.6           37.0
#
# [10770 rows x 3 columns]

# %%
# take the max weeks a song is on the top 40 and show the highest rankers
energy_ranking2 = energy_ranking_max2.sort_values("Peak Position", ascending=True).dropna(subset=['Peak Position'])
energy_ranking2
# Out:
#                                  Song Energy Category  Peak Position
# 46808               Whatever You Like     0.61 to 0.8            1.0
# 46427               What Do You Mean?     0.41 to 0.6            1.0
# 10177            Doo Wop (That Thing)     0.41 to 0.6            1.0
# 14777             HIGHEST IN THE ROOM     0.41 to 0.6            1.0
# 25188        Look What You Made Me Do     0.61 to 0.8            1.0
# ...                               ...             ...            ...
# 21433                 It Must Be Love     0.61 to 0.8           40.0
# 17676     I Don't Know Where To Start     0.21 to 0.4           40.0
# 11757  Fanny (Be Tender With My Love)     0.41 to 0.6           40.0
# 29038              Never Ending Story     0.61 to 0.8           40.0
# 8068                Crying Out For Me     0.61 to 0.8           40.0
#
# [10770 rows x 3 columns]

# %%
#energy_barchart2 = energy_ranking2.plot(kind='bar')
#energy_barchart2.set_xlabel('Energy Category')
#energy_barchart2.set_ylabel('Weeks on Chart')
#plt.show()

# %%
energy_groups2 = energy_ranking2.groupby('Energy Category')
energy_category2 = energy_groups2['Peak Position'].mean()

# %%
energy_cat_chart2 = energy_category2.plot.bar(title ='Energy on Charts')
energy_cat_chart2.set_xlabel('Energy Category')
energy_cat_chart2.set_ylabel('Avg Peak Position')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
merged_df = pd.merge(loudness_df, energy_df, on=["Performer", "Song", "Genre", "Peak Position",
                                                "Weeks on Chart"], how='outer').dropna()
merged_df = merged_df[["Performer", "Song", "Genre", "Loudness", "Loudness Category",
                       "Energy", "Energy Category", "Peak Position", "Weeks on Chart"]]

merged_df
# Out:
#                          Performer                 Song  \
# 0       Lady Gaga & Bradley Cooper              Shallow
# 1       Lady Gaga & Bradley Cooper              Shallow
# 2       Lady Gaga & Bradley Cooper              Shallow
# 3       Lady Gaga & Bradley Cooper              Shallow
# 4       Lady Gaga & Bradley Cooper              Shallow
# ...                            ...                  ...
# 117318               Solomon Burke  Tonight's The Night
# 117319               Solomon Burke  Tonight's The Night
# 117320               Solomon Burke  Tonight's The Night
# 117321               Solomon Burke  Tonight's The Night
# 117322               Solomon Burke  Tonight's The Night
#
#                                                     Genre  Loudness  \
# 0                                    ['dance pop', 'pop']    -6.362
# 1                                    ['dance pop', 'pop']    -6.362
# 2                                    ['dance pop', 'pop']    -6.362
# 3                                    ['dance pop', 'pop']    -6.362
# 4                                    ['dance pop', 'pop']    -6.362
# ...                                                   ...       ...
# 117318  ['brill building pop', 'classic soul', 'funk',...    -9.534
# 117319  ['brill building pop', 'classic soul', 'funk',...    -9.534
# 117320  ['brill building pop', 'classic soul', 'funk',...    -9.534
# 117321  ['brill building pop', 'classic soul', 'funk',...    -9.534
# 117322  ['brill building pop', 'classic soul', 'funk',...    -9.534
#
#        Loudness Category  Energy Energy Category  Peak Position  \
# 0              -10 to -6   0.385     0.21 to 0.4           28.0
# 1              -10 to -6   0.385     0.21 to 0.4           28.0
# 2              -10 to -6   0.385     0.21 to 0.4           28.0
# 3              -10 to -6   0.385     0.21 to 0.4           28.0
# 4              -10 to -6   0.385     0.21 to 0.4            5.0
# ...                  ...     ...             ...            ...
# 117318         -10 to -6   0.476     0.41 to 0.6           32.0
# 117319         -10 to -6   0.476     0.41 to 0.6           29.0
# 117320         -10 to -6   0.476     0.41 to 0.6           28.0
# 117321         -10 to -6   0.476     0.41 to 0.6           28.0
# 117322         -10 to -6   0.476     0.41 to 0.6           28.0
#
#         Weeks on Chart
# 0                  1.0
# 1                  1.0
# 2                  1.0
# 3                  1.0
# 4                  8.0
# ...                ...
# 117318             6.0
# 117319             7.0
# 117320             8.0
# 117321             9.0
# 117322            10.0
#
# [117323 rows x 9 columns]

# %%
plt.scatter(merged_df['Loudness'],merged_df['Energy'],c=merged_df['Peak Position'])
clb = plt.colorbar()
plt.xlabel("Loudness")
plt.ylabel("Energy")
clb.set_label("Peak Position")
plt.show()

# %%
plt.scatter(merged_df['Loudness'],merged_df['Energy'],c=merged_df['Weeks on Chart'])
clb = plt.colorbar()
plt.xlabel("Loudness")
plt.ylabel("Energy")
clb.set_label("Weeks on Chart")
plt.show()
